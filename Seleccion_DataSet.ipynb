# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorPabloCristina/DataSet-Proyecto-F-CH/blob/main/Seleccion_DataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DataSet Mundial

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Data Science/Datasets/FIFA22_official_data.csv")
df
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 16705  240558    18 L. Clayton   17
# 16706  262846         �. Dobre   20
# 16707  241317   21 Xue Qinghao   19
# 16708  259646        A. Shaikh   18
# 16709  178453    07 A. Censori   17
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# ...

# %%
df = pd.read_excel("/content/drive/MyDrive/Data Science/Datasets/AC_EQ_ASG_AUSENCIAS_PERSON.xlsx")
df
# Out:
#     Ausencias del Personal a Cargo                      286  \
# 0                               ID                   Nombre
# 1                           569350  Angel Ricardo Rodriguez
# 2                           569350  Angel Ricardo Rodriguez
# 3                           569350  Angel Ricardo Rodriguez
# 4                           569350  Angel Ricardo Rodriguez
# ..                             ...                      ...
# 282                         574818         Mauro Omar Acuña
# 283                         574818         Mauro Omar Acuña
# 284                         574818         Mauro Omar Acuña
# 285                         574818         Mauro Omar Acuña
# 286                         574818         Mauro Omar Acuña
#
#               Unnamed: 2           Unnamed: 3   Unnamed: 4    Unnamed: 5  \
# 0                 F Inic            F Regreso  Hora Inicio  Hora Regreso
# 1    2022-01-06 00:00:00  2022-01-06 00:00:00          NaN           NaN
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd


df = pd.read_excel("/content/drive/MyDrive/Data Science/Datasets/Analisis AUX - Dic 22.xlsx")
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#     Unnamed: 0                 Unnamed: 1      Unnamed: 2      Unnamed: 3  \
# 0          NaN  Variacion a nivel Negocio             NaN             NaN
# 1          NaN                        NaN             NaN             NaN
# 2          NaN                        NaN        SFS 2021        SFS 2022
# 3          NaN                     Bolsas       287750.71   284443.667688
# 4          NaN                     Cartón    1495608.6332  1514238.568435
# 5          NaN                   Flexible   623638.618816   631126.258816
# 6          NaN            Papel Reciclado   700217.383023   585433.475326
# 7          NaN               Papel Virgen  2649060.016868  2577198.005368
# 8          NaN              Total general  5756275.361907  5592439.975633
# 9          NaN                        NaN             NaN             NaN
# ...

# %%
import pandas as pd
df = pd.read_excel("/content/drive/MyDrive/Data Science/Datasets/Fallos.xlsx")
df
# Out:
#        INDISPONIBILIDAD TOTAL                    Unnamed: 1  \
# 0                         NaN                           NaN
# 1         Indisponibilidad C7                           NaN
# 2                      Equipo                            C7
# 3                       Fecha                       (Todas)
# 4                         NaN                           NaN
# 5                         NaN                       Valores
# 6           Etiquetas de fila          % Fallos Consolidado
# 7                        2020                      0.046102
# 8                        2021                      0.032223
# 9                        2022                      0.040993
# 10                      Enero                       0.03017
# 11                    Febrero                       0.05911
# 12                      Marzo                             0
# 13                      Abril                             0
# 14                       Mayo                             0
# ...

# %%
import pandas as pd
df = pd.read_excel("/content/drive/MyDrive/Data Science/Datasets/OT grales de fabrica limpio.xlsx")
df
# Out:
#        Número orden Tipo orden          Descripción tipo orden Tipo OT  \
# 0          30880294         WW    ARMAR PAR CORRUGADOR BACK UP       7
# 1          30880600         WW     CAMBIO DE SOPORTES DE MOLAS       7
# 2          30880877         WW   MP MEC INSPECCION SEMANAL SUP       7
# 3          30880884         WW   MP MEC INSPECCION SEMANAL INF       7
# 4          30880959         WW  MP-8401-MEC-C7-3M-MPRE ENFR. A       7
# ...             ...        ...                             ...     ...
# 11015      35944665         WW                limpiar rodillos       6
# 11016      35944667         WW                   limpiar batea       6
# 11017      35944668         WW    limpiar pulmon en cabezal js       6
# 11018      35959781         WM      MP-USI-1S CORRUGADORA GRAL       O
# 11019      35959782         WM                 MP-MEC-1M EMP 5       O
#
#       Descripción tipo OT Prioridad           Descripción prioridad  \
# ...

# %%
import pandas as pd
df = pd.read_excel("/content/drive/MyDrive/Data Science/Datasets/Ordenes_compra.xlsx")
df
# Out:
#        Número orden  Cantidad por recibir  UM  Importe por recibir  \
# 0             59461                   1.0  UN                 0.00
# 1             60334                   0.0  UN                 0.00
# 2             60334                   0.0  UN                 0.00
# 3             69288                   1.0  UN              8838.32
# 4             70452                   0.0  MT                 0.00
# ...             ...                   ...  ..                  ...
# 10161      52752286                  40.0  UN               320.58
# 10162      52752286                  50.0  UN             18032.40
# 10163      52752289                   2.0  KG              6439.57
# 10164      52752433                   2.0  UN            256861.52
# 10165      52752999                  10.0  UN            197775.66
#
#        Destino envío Tp ord  Cía orden  Orden cambio  Nº prove  \
# 0           12063303     6I          6             0  12060103
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Data Science/Datasets/calidad-aire.csv")
df
# Out:
#                      FECHA  HORA CO_CENTENARIO NO2_CENTENARIO PM10_CENTENARIO  \
# 0       20JAN2010:00:00:00     2           s/d            s/d             NaN
# 1       20JAN2010:00:00:00     3           s/d            s/d             NaN
# 2       20JAN2010:00:00:00     9           s/d            s/d             NaN
# 3       11JAN2010:00:00:00     4           s/d            s/d             NaN
# 4       11JAN2010:00:00:00     7           s/d            s/d             NaN
# ...                    ...   ...           ...            ...             ...
# 115981  20JUL2015:00:00:00    15          0.44             13              22
# 115982  12NOV2011:00:00:00    21          0.39             35              26
# 115983  16MAR2011:00:00:00    11           s/d             18             s/d
# 115984  29SEP2010:00:00:00    21           s/d             23             NaN
# 115985  17NOV2013:00:00:00     8          0.31            s/d              22
#
# ...

# %%
import pandas as pd
df = pd.read_excel("/content/drive/MyDrive/Data Science/Datasets/fallos limpio.xlsx")
df
# Out:
#      Periodo     Mes Linea     N°           Fecha        Ini       Fin      \
# 0     2017/1    2017    C7  230.0            1/12/2017       NaN       NaN
# 1     2017/1    2017    C7  231.0            1/12/2017       NaN       NaN
# 2     2017/1    2017    C7  233.0            1/12/2017       NaN       NaN
# 3     2017/1    2017    C7  229.0            1/12/2017       NaN       NaN
# 4     2017/1    2017    C7  232.0            1/12/2017       NaN       NaN
# ...      ...     ...   ...    ...                  ...       ...       ...
# 3599  2023/3  Mar-23    C7   15.0  2023-03-08 00:00:00  22:43:00  22:48:00
# 3600  2023/3  Mar-23    C7   17.0  2023-03-08 00:00:00  23:10:00  23:24:00
# 3601  2023/3  Mar-23    C7    2.0  2023-03-09 00:00:00  02:07:00  02:11:00
# 3602  2023/3  Mar-23    C7    3.0  2023-03-09 00:00:00  04:31:00  04:39:00
# 3603  2023/3  Mar-23    C7   12.0  2023-03-09 00:00:00  23:34:00  23:42:00
#
# ...
